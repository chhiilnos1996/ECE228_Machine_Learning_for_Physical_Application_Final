# %% [markdown]
# # Whale Detection Challenge : MNASNet 1.0

# %% [markdown]
# Method overview : FFT to convert the sound tracks into spectrograms, and apply distinct preprocessing methods such as clipping, noise removal, PCEN and filters. After preprocessing we feed the spectrograms into state of the art light CNN models such as Resnet 18, VGG 16 or GoogleNet to identify right whale call patterns and perform classification. We may also try the removal of pooling layers in the networks and see if it causes better outcome.

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.3.1
# Torchvision Version:  0.4.2

# %% [markdown]
# ## Import and Load Data

# %%
num_classes = 2
batch_size = 32
num_epochs = 200
feature_extract = True
groups = 3
vis_batch = 4

# %%
data_dir = "data/"
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x+"_prep_10/"), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=8) for x in ['train', 'val']}

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Initializing Datasets and Dataloaders...

# %% [markdown]
# ## Model

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

def initialize_model(num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = models.mnasnet1_0(pretrained=True)
    set_parameter_requires_grad(model_ft, feature_extract)
    model_ft.classifier[1] = nn.Linear(1280, num_classes)
    input_size = 224  
    return model_ft, input_size

# Initialize the model for this run
model_ft, input_size = initialize_model(num_classes, feature_extract, use_pretrained=True)

# Print the model we just instantiated
print(model_ft)
# Out:
# MNASNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (8): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(16, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (4): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (4): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (4): BatchNorm2d(72, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(40, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (4): BatchNorm2d(120, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(40, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (4): BatchNorm2d(120, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(40, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#           (4): BatchNorm2d(240, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(80, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#           (4): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(80, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#           (4): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(80, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (4): BatchNorm2d(480, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(576, 576, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=576, bias=False)
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(192, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (1): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (4): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(192, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (2): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (4): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(192, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#       (3): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (4): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(192, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#           (4): BatchNorm2d(1152, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#           (6): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (7): BatchNorm2d(320, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (15): BatchNorm2d(1280, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## Training Section

# %% [markdown]
# ### training fuction

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()
    history = {'train_loss':[],'train_acc':[],'val_loss':[],'val_acc':[]}
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                # zero the parameter gradients
                optimizer.zero_grad()
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'train':
                history['train_loss'].append(epoch_loss)
                history['train_acc'].append(epoch_acc)
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                history['val_loss'].append(epoch_loss)
                history['val_acc'].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history, best_acc

# %% [markdown]
# ### optimizer

# %%
# Send the model to GPU
model_ft = model_ft.to(device)

# Gather the parameters to be optimized/updated in this run. If we are
#  finetuning we will be updating all parameters. However, if we are
#  doing feature extract method, we will only update the parameters
#  that we have just initialized, i.e. the parameters with requires_grad
#  is True.
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %% [markdown]
# ### run and save model

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, hist, best_acc = train_model(model_ft, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
torch.save(model_ft.state_dict(), 'model_weight/mnasnet1_'+str(num_epochs))
# Out:
# Epoch 0/199
# ----------
# train Loss: 0.4839 Acc: 0.7717
# val Loss: 0.5976 Acc: 0.7467
#
# Epoch 1/199
# ----------
# train Loss: 0.4233 Acc: 0.8050
# val Loss: 0.5861 Acc: 0.7393
#
# Epoch 2/199
# ----------
# train Loss: 0.3987 Acc: 0.8230
# val Loss: 0.5839 Acc: 0.7400
#
# Epoch 3/199
# ----------
# train Loss: 0.3892 Acc: 0.8250
# val Loss: 0.5879 Acc: 0.7367
#
# Epoch 4/199
# ----------
# train Loss: 0.3785 Acc: 0.8303
# val Loss: 0.5885 Acc: 0.7370
#
# Epoch 5/199
# ----------
# train Loss: 0.3769 Acc: 0.8400
# val Loss: 0.5516 Acc: 0.7483
#
# Epoch 6/199
# ----------
# train Loss: 0.3706 Acc: 0.8367
# val Loss: 0.5283 Acc: 0.7587
#
# Epoch 7/199
# ----------
# train Loss: 0.3692 Acc: 0.8333
# val Loss: 0.5237 Acc: 0.7607
#
# Epoch 8/199
# ----------
# train Loss: 0.3636 Acc: 0.8373
# val Loss: 0.5386 Acc: 0.7570
#
# Epoch 9/199
# ----------
# train Loss: 0.3657 Acc: 0.8360
# val Loss: 0.5297 Acc: 0.7570
#
# Epoch 10/199
# ----------
# train Loss: 0.3543 Acc: 0.8453
# val Loss: 0.5226 Acc: 0.7587
#
# Epoch 11/199
# ----------
# train Loss: 0.3465 Acc: 0.8493
# val Loss: 0.5061 Acc: 0.7657
#
# Epoch 12/199
# ----------
# train Loss: 0.3431 Acc: 0.8460
# val Loss: 0.5050 Acc: 0.7653
#
# Epoch 13/199
# ----------
# train Loss: 0.3489 Acc: 0.8500
# val Loss: 0.5036 Acc: 0.7660
#
# Epoch 14/199
# ----------
# train Loss: 0.3488 Acc: 0.8460
# val Loss: 0.4966 Acc: 0.7663
#
# Epoch 15/199
# ----------
# train Loss: 0.3444 Acc: 0.8477
# val Loss: 0.4952 Acc: 0.7667
#
# Epoch 16/199
# ----------
# train Loss: 0.3473 Acc: 0.8447
# val Loss: 0.4960 Acc: 0.7670
#
# Epoch 17/199
# ----------
# train Loss: 0.3406 Acc: 0.8490
# val Loss: 0.4958 Acc: 0.7667
#
# Epoch 18/199
# ----------
# train Loss: 0.3303 Acc: 0.8603
# val Loss: 0.4981 Acc: 0.7677
#
# Epoch 19/199
# ----------
# train Loss: 0.3325 Acc: 0.8490
# val Loss: 0.5051 Acc: 0.7663
#
# Epoch 20/199
# ----------
# train Loss: 0.3347 Acc: 0.8483
# val Loss: 0.5000 Acc: 0.7667
#
# Epoch 21/199
# ----------
# train Loss: 0.3337 Acc: 0.8557
# val Loss: 0.5010 Acc: 0.7677
#
# Epoch 22/199
# ----------
# train Loss: 0.3341 Acc: 0.8497
# val Loss: 0.5047 Acc: 0.7670
#
# Epoch 23/199
# ----------
# train Loss: 0.3317 Acc: 0.8453
# val Loss: 0.5071 Acc: 0.7667
#
# Epoch 24/199
# ----------
# train Loss: 0.3367 Acc: 0.8540
# val Loss: 0.5094 Acc: 0.7670
#
# Epoch 25/199
# ----------
# train Loss: 0.3260 Acc: 0.8593
# val Loss: 0.5096 Acc: 0.7673
#
# Epoch 26/199
# ----------
# train Loss: 0.3351 Acc: 0.8513
# val Loss: 0.5205 Acc: 0.7673
#
# Epoch 27/199
# ----------
# train Loss: 0.3232 Acc: 0.8547
# val Loss: 0.5156 Acc: 0.7673
#
# Epoch 28/199
# ----------
# train Loss: 0.3208 Acc: 0.8620
# val Loss: 0.5141 Acc: 0.7670
#
# Epoch 29/199
# ----------
# train Loss: 0.3323 Acc: 0.8540
# val Loss: 0.5106 Acc: 0.7670
#
# Epoch 30/199
# ----------
# train Loss: 0.3313 Acc: 0.8523
# val Loss: 0.5145 Acc: 0.7670
#
# Epoch 31/199
# ----------
# train Loss: 0.3270 Acc: 0.8593
# val Loss: 0.5179 Acc: 0.7673
#
# Epoch 32/199
# ----------
# train Loss: 0.3184 Acc: 0.8607
# val Loss: 0.5138 Acc: 0.7677
#
# Epoch 33/199
# ----------
# train Loss: 0.3243 Acc: 0.8547
# val Loss: 0.5111 Acc: 0.7677
#
# Epoch 34/199
# ----------
# train Loss: 0.3264 Acc: 0.8603
# val Loss: 0.4968 Acc: 0.7697
#
# Epoch 35/199
# ----------
# train Loss: 0.3336 Acc: 0.8537
# val Loss: 0.4873 Acc: 0.7730
#
# Epoch 36/199
# ----------
# train Loss: 0.3243 Acc: 0.8587
# val Loss: 0.5002 Acc: 0.7697
#
# Epoch 37/199
# ----------
# train Loss: 0.3216 Acc: 0.8550
# val Loss: 0.4882 Acc: 0.7733
#
# Epoch 38/199
# ----------
# train Loss: 0.3266 Acc: 0.8570
# val Loss: 0.4758 Acc: 0.7770
#
# Epoch 39/199
# ----------
# train Loss: 0.3232 Acc: 0.8553
# val Loss: 0.4757 Acc: 0.7767
#
# Epoch 40/199
# ----------
# train Loss: 0.3158 Acc: 0.8620
# val Loss: 0.5005 Acc: 0.7707
#
# Epoch 41/199
# ----------
# train Loss: 0.3172 Acc: 0.8573
# val Loss: 0.4828 Acc: 0.7733
#
# Epoch 42/199
# ----------
# train Loss: 0.3176 Acc: 0.8543
# val Loss: 0.4711 Acc: 0.7777
#
# Epoch 43/199
# ----------
# train Loss: 0.3088 Acc: 0.8703
# val Loss: 0.4611 Acc: 0.7837
#
# Epoch 44/199
# ----------
# train Loss: 0.3198 Acc: 0.8650
# val Loss: 0.4721 Acc: 0.7790
#
# Epoch 45/199
# ----------
# train Loss: 0.3185 Acc: 0.8603
# val Loss: 0.4560 Acc: 0.7840
#
# Epoch 46/199
# ----------
# train Loss: 0.3240 Acc: 0.8547
# val Loss: 0.4562 Acc: 0.7817
#
# Epoch 47/199
# ----------
# train Loss: 0.3148 Acc: 0.8600
# val Loss: 0.4500 Acc: 0.7857
#
# Epoch 48/199
# ----------
# train Loss: 0.3200 Acc: 0.8553
# val Loss: 0.4641 Acc: 0.7790
#
# Epoch 49/199
# ----------
# train Loss: 0.3197 Acc: 0.8523
# val Loss: 0.4501 Acc: 0.7850
#
# Epoch 50/199
# ----------
# train Loss: 0.3253 Acc: 0.8573
# val Loss: 0.4489 Acc: 0.7850
#
# Epoch 51/199
# ----------
# train Loss: 0.3100 Acc: 0.8577
# val Loss: 0.4518 Acc: 0.7830
#
# Epoch 52/199
# ----------
# train Loss: 0.3175 Acc: 0.8550
# val Loss: 0.4580 Acc: 0.7830
#
# Epoch 53/199
# ----------
# train Loss: 0.3283 Acc: 0.8530
# val Loss: 0.4503 Acc: 0.7867
#
# Epoch 54/199
# ----------
# train Loss: 0.3228 Acc: 0.8540
# val Loss: 0.4362 Acc: 0.7900
#
# Epoch 55/199
# ----------
# train Loss: 0.3196 Acc: 0.8617
# val Loss: 0.4378 Acc: 0.7893
#
# Epoch 56/199
# ----------
# train Loss: 0.3157 Acc: 0.8623
# val Loss: 0.4439 Acc: 0.7880
#
# Epoch 57/199
# ----------
# train Loss: 0.3155 Acc: 0.8567
# val Loss: 0.4352 Acc: 0.7907
#
# Epoch 58/199
# ----------
# train Loss: 0.3205 Acc: 0.8560
# val Loss: 0.4609 Acc: 0.7840
#
# Epoch 59/199
# ----------
# train Loss: 0.3119 Acc: 0.8597
# val Loss: 0.4476 Acc: 0.7870
#
# Epoch 60/199
# ----------
# train Loss: 0.3094 Acc: 0.8670
# val Loss: 0.4344 Acc: 0.7913
#
# Epoch 61/199
# ----------
# train Loss: 0.3116 Acc: 0.8627
# val Loss: 0.4305 Acc: 0.7937
#
# Epoch 62/199
# ----------
# train Loss: 0.3262 Acc: 0.8583
# val Loss: 0.4463 Acc: 0.7883
#
# Epoch 63/199
# ----------
# train Loss: 0.3173 Acc: 0.8557
# val Loss: 0.4159 Acc: 0.8020
#
# Epoch 64/199
# ----------
# train Loss: 0.3193 Acc: 0.8643
# val Loss: 0.4505 Acc: 0.7870
#
# Epoch 65/199
# ----------
# train Loss: 0.3183 Acc: 0.8573
# val Loss: 0.4227 Acc: 0.7963
#
# Epoch 66/199
# ----------
# train Loss: 0.3040 Acc: 0.8677
# val Loss: 0.4212 Acc: 0.7987
#
# Epoch 67/199
# ----------
# train Loss: 0.3103 Acc: 0.8690
# val Loss: 0.4323 Acc: 0.7917
#
# Epoch 68/199
# ----------
# train Loss: 0.3157 Acc: 0.8647
# val Loss: 0.4172 Acc: 0.8023
#
# Epoch 69/199
# ----------
# train Loss: 0.2997 Acc: 0.8723
# val Loss: 0.4078 Acc: 0.8050
#
# Epoch 70/199
# ----------
# train Loss: 0.3090 Acc: 0.8640
# val Loss: 0.4166 Acc: 0.8023
#
# Epoch 71/199
# ----------
# train Loss: 0.3056 Acc: 0.8663
# val Loss: 0.4099 Acc: 0.8057
#
# Epoch 72/199
# ----------
# train Loss: 0.3021 Acc: 0.8717
# val Loss: 0.4082 Acc: 0.8067
#
# Epoch 73/199
# ----------
# train Loss: 0.3083 Acc: 0.8573
# val Loss: 0.4111 Acc: 0.8063
#
# Epoch 74/199
# ----------
# train Loss: 0.3094 Acc: 0.8650
# val Loss: 0.3999 Acc: 0.8110
#
# Epoch 75/199
# ----------
# train Loss: 0.3061 Acc: 0.8630
# val Loss: 0.4099 Acc: 0.8053
#
# Epoch 76/199
# ----------
# train Loss: 0.3090 Acc: 0.8640
# val Loss: 0.3939 Acc: 0.8147
#
# Epoch 77/199
# ----------
# train Loss: 0.3046 Acc: 0.8650
# val Loss: 0.3948 Acc: 0.8133
#
# Epoch 78/199
# ----------
# train Loss: 0.3089 Acc: 0.8640
# val Loss: 0.3963 Acc: 0.8107
#
# Epoch 79/199
# ----------
# train Loss: 0.3129 Acc: 0.8637
# val Loss: 0.3978 Acc: 0.8097
#
# Epoch 80/199
# ----------
# train Loss: 0.3121 Acc: 0.8617
# val Loss: 0.3870 Acc: 0.8253
#
# Epoch 81/199
# ----------
# train Loss: 0.3032 Acc: 0.8597
# val Loss: 0.3863 Acc: 0.8230
#
# Epoch 82/199
# ----------
# train Loss: 0.3058 Acc: 0.8660
# val Loss: 0.4039 Acc: 0.8107
#
# Epoch 83/199
# ----------
# train Loss: 0.3126 Acc: 0.8580
# val Loss: 0.3887 Acc: 0.8183
#
# Epoch 84/199
# ----------
# train Loss: 0.3075 Acc: 0.8660
# val Loss: 0.3837 Acc: 0.8237
#
# Epoch 85/199
# ----------
# train Loss: 0.3060 Acc: 0.8620
# val Loss: 0.3810 Acc: 0.8257
#
# Epoch 86/199
# ----------
# train Loss: 0.3055 Acc: 0.8633
# val Loss: 0.3795 Acc: 0.8270
#
# Epoch 87/199
# ----------
# train Loss: 0.3102 Acc: 0.8580
# val Loss: 0.3798 Acc: 0.8270
#
# Epoch 88/199
# ----------
# train Loss: 0.2996 Acc: 0.8660
# val Loss: 0.3793 Acc: 0.8277
#
# Epoch 89/199
# ----------
# train Loss: 0.3051 Acc: 0.8630
# val Loss: 0.3791 Acc: 0.8283
#
# Epoch 90/199
# ----------
# train Loss: 0.2999 Acc: 0.8633
# val Loss: 0.3809 Acc: 0.8220
#
# Epoch 91/199
# ----------
# train Loss: 0.3169 Acc: 0.8640
# val Loss: 0.3774 Acc: 0.8277
#
# Epoch 92/199
# ----------
# train Loss: 0.3247 Acc: 0.8550
# val Loss: 0.3781 Acc: 0.8267
#
# Epoch 93/199
# ----------
# train Loss: 0.3039 Acc: 0.8653
# val Loss: 0.3886 Acc: 0.8197
#
# Epoch 94/199
# ----------
# train Loss: 0.3184 Acc: 0.8510
# val Loss: 0.3758 Acc: 0.8287
#
# Epoch 95/199
# ----------
# train Loss: 0.2985 Acc: 0.8680
# val Loss: 0.3763 Acc: 0.8273
#
# Epoch 96/199
# ----------
# train Loss: 0.3110 Acc: 0.8643
# val Loss: 0.3742 Acc: 0.8290
#
# Epoch 97/199
# ----------
# train Loss: 0.3089 Acc: 0.8617
# val Loss: 0.3736 Acc: 0.8307
#
# Epoch 98/199
# ----------
# train Loss: 0.3061 Acc: 0.8690
# val Loss: 0.3731 Acc: 0.8310
#
# Epoch 99/199
# ----------
# train Loss: 0.3222 Acc: 0.8553
# val Loss: 0.3767 Acc: 0.8287
#
# Epoch 100/199
# ----------
# train Loss: 0.3037 Acc: 0.8627
# val Loss: 0.3749 Acc: 0.8280
#
# Epoch 101/199
# ----------
# train Loss: 0.3091 Acc: 0.8650
# val Loss: 0.3834 Acc: 0.8273
#
# Epoch 102/199
# ----------
# train Loss: 0.3024 Acc: 0.8607
# val Loss: 0.3760 Acc: 0.8293
#
# Epoch 103/199
# ----------
# train Loss: 0.2975 Acc: 0.8720
# val Loss: 0.3721 Acc: 0.8277
#
# Epoch 104/199
# ----------
# train Loss: 0.3122 Acc: 0.8680
# val Loss: 0.3713 Acc: 0.8270
#
# Epoch 105/199
# ----------
# train Loss: 0.3068 Acc: 0.8650
# val Loss: 0.3740 Acc: 0.8320
#
# Epoch 106/199
# ----------
# train Loss: 0.3050 Acc: 0.8700
# val Loss: 0.3710 Acc: 0.8340
#
# Epoch 107/199
# ----------
# train Loss: 0.3027 Acc: 0.8707
# val Loss: 0.3727 Acc: 0.8293
#
# Epoch 108/199
# ----------
# train Loss: 0.3096 Acc: 0.8567
# val Loss: 0.3705 Acc: 0.8327
#
# Epoch 109/199
# ----------
# train Loss: 0.3068 Acc: 0.8610
# val Loss: 0.3689 Acc: 0.8310
#
# Epoch 110/199
# ----------
# train Loss: 0.3133 Acc: 0.8660
# val Loss: 0.3678 Acc: 0.8303
#
# Epoch 111/199
# ----------
# train Loss: 0.3039 Acc: 0.8647
# val Loss: 0.3677 Acc: 0.8297
#
# Epoch 112/199
# ----------
# train Loss: 0.2921 Acc: 0.8710
# val Loss: 0.3671 Acc: 0.8303
#
# Epoch 113/199
# ----------
# train Loss: 0.3062 Acc: 0.8620
# val Loss: 0.3670 Acc: 0.8313
#
# Epoch 114/199
# ----------
# train Loss: 0.3065 Acc: 0.8660
# val Loss: 0.3666 Acc: 0.8327
#
# Epoch 115/199
# ----------
# train Loss: 0.2973 Acc: 0.8733
# val Loss: 0.3761 Acc: 0.8350
#
# Epoch 116/199
# ----------
# train Loss: 0.3011 Acc: 0.8713
# val Loss: 0.3658 Acc: 0.8323
#
# Epoch 117/199
# ----------
# train Loss: 0.2989 Acc: 0.8690
# val Loss: 0.3695 Acc: 0.8357
#
# Epoch 118/199
# ----------
# train Loss: 0.3075 Acc: 0.8663
# val Loss: 0.3650 Acc: 0.8330
#
# Epoch 119/199
# ----------
# train Loss: 0.3103 Acc: 0.8620
# val Loss: 0.3648 Acc: 0.8327
#
# Epoch 120/199
# ----------
# train Loss: 0.3015 Acc: 0.8620
# val Loss: 0.3664 Acc: 0.8367
#
# Epoch 121/199
# ----------
# train Loss: 0.2957 Acc: 0.8713
# val Loss: 0.3737 Acc: 0.8353
#
# Epoch 122/199
# ----------
# train Loss: 0.2997 Acc: 0.8693
# val Loss: 0.3643 Acc: 0.8350
#
# Epoch 123/199
# ----------
# train Loss: 0.3060 Acc: 0.8660
# val Loss: 0.3671 Acc: 0.8387
#
# Epoch 124/199
# ----------
# train Loss: 0.3130 Acc: 0.8540
# val Loss: 0.3641 Acc: 0.8357
#
# Epoch 125/199
# ----------
# train Loss: 0.3171 Acc: 0.8573
# val Loss: 0.3664 Acc: 0.8393
#
# Epoch 126/199
# ----------
# train Loss: 0.3094 Acc: 0.8640
# val Loss: 0.3633 Acc: 0.8373
#
# Epoch 127/199
# ----------
# train Loss: 0.3044 Acc: 0.8597
# val Loss: 0.3682 Acc: 0.8363
#
# Epoch 128/199
# ----------
# train Loss: 0.3008 Acc: 0.8670
# val Loss: 0.3652 Acc: 0.8400
#
# Epoch 129/199
# ----------
# train Loss: 0.3147 Acc: 0.8647
# val Loss: 0.3636 Acc: 0.8437
#
# Epoch 130/199
# ----------
# train Loss: 0.3094 Acc: 0.8680
# val Loss: 0.3782 Acc: 0.8373
#
# Epoch 131/199
# ----------
# train Loss: 0.3058 Acc: 0.8643
# val Loss: 0.3653 Acc: 0.8420
#
# Epoch 132/199
# ----------
# train Loss: 0.3182 Acc: 0.8603
# val Loss: 0.3626 Acc: 0.8393
#
# Epoch 133/199
# ----------
# train Loss: 0.3090 Acc: 0.8600
# val Loss: 0.3632 Acc: 0.8400
#
# Epoch 134/199
# ----------
# train Loss: 0.3117 Acc: 0.8600
# val Loss: 0.3668 Acc: 0.8403
#
# Epoch 135/199
# ----------
# train Loss: 0.3115 Acc: 0.8610
# val Loss: 0.3625 Acc: 0.8400
#
# Epoch 136/199
# ----------
# train Loss: 0.3079 Acc: 0.8720
# val Loss: 0.3635 Acc: 0.8427
#
# Epoch 137/199
# ----------
# train Loss: 0.3096 Acc: 0.8640
# val Loss: 0.3623 Acc: 0.8383
#
# Epoch 138/199
# ----------
# train Loss: 0.3024 Acc: 0.8670
# val Loss: 0.3627 Acc: 0.8423
#
# Epoch 139/199
# ----------
# train Loss: 0.3063 Acc: 0.8680
# val Loss: 0.3647 Acc: 0.8453
#
# Epoch 140/199
# ----------
# train Loss: 0.3131 Acc: 0.8623
# val Loss: 0.3623 Acc: 0.8427
#
# Epoch 141/199
# ----------
# train Loss: 0.3045 Acc: 0.8710
# val Loss: 0.3624 Acc: 0.8407
#
# Epoch 142/199
# ----------
# train Loss: 0.3063 Acc: 0.8640
# val Loss: 0.3649 Acc: 0.8410
#
# Epoch 143/199
# ----------
# train Loss: 0.3041 Acc: 0.8637
# val Loss: 0.3630 Acc: 0.8420
#
# Epoch 144/199
# ----------
# train Loss: 0.3160 Acc: 0.8570
# val Loss: 0.3630 Acc: 0.8443
#
# Epoch 145/199
# ----------
# train Loss: 0.3016 Acc: 0.8720
# val Loss: 0.3624 Acc: 0.8397
#
# Epoch 146/199
# ----------
# train Loss: 0.3155 Acc: 0.8600
# val Loss: 0.3642 Acc: 0.8433
#
# Epoch 147/199
# ----------
# train Loss: 0.3046 Acc: 0.8640
# val Loss: 0.3650 Acc: 0.8410
#
# Epoch 148/199
# ----------
# train Loss: 0.2972 Acc: 0.8673
# val Loss: 0.3629 Acc: 0.8450
#
# Epoch 149/199
# ----------
# train Loss: 0.3051 Acc: 0.8583
# val Loss: 0.3631 Acc: 0.8403
#
# Epoch 150/199
# ----------
# train Loss: 0.3084 Acc: 0.8643
# val Loss: 0.3672 Acc: 0.8403
#
# Epoch 151/199
# ----------
# train Loss: 0.3015 Acc: 0.8693
# val Loss: 0.3632 Acc: 0.8433
#
# Epoch 152/199
# ----------
# train Loss: 0.3049 Acc: 0.8657
# val Loss: 0.3642 Acc: 0.8440
#
# Epoch 153/199
# ----------
# train Loss: 0.2970 Acc: 0.8650
# val Loss: 0.3655 Acc: 0.8423
#
# Epoch 154/199
# ----------
# train Loss: 0.3120 Acc: 0.8597
# val Loss: 0.3654 Acc: 0.8447
#
# Epoch 155/199
# ----------
# train Loss: 0.3006 Acc: 0.8683
# val Loss: 0.3646 Acc: 0.8417
#
# Epoch 156/199
# ----------
# train Loss: 0.3224 Acc: 0.8563
# val Loss: 0.3703 Acc: 0.8410
#
# Epoch 157/199
# ----------
# train Loss: 0.3095 Acc: 0.8660
# val Loss: 0.3652 Acc: 0.8423
#
# Epoch 158/199
# ----------
# train Loss: 0.3026 Acc: 0.8633
# val Loss: 0.3667 Acc: 0.8430
#
# Epoch 159/199
# ----------
# train Loss: 0.3165 Acc: 0.8623
# val Loss: 0.3677 Acc: 0.8437
#
# Epoch 160/199
# ----------
# train Loss: 0.2952 Acc: 0.8667
# val Loss: 0.3654 Acc: 0.8403
#
# Epoch 161/199
# ----------
# train Loss: 0.3041 Acc: 0.8630
# val Loss: 0.3695 Acc: 0.8393
#
# Epoch 162/199
# ----------
# train Loss: 0.3155 Acc: 0.8580
# val Loss: 0.3682 Acc: 0.8427
#
# Epoch 163/199
# ----------
# train Loss: 0.3009 Acc: 0.8663
# val Loss: 0.3656 Acc: 0.8420
#
# Epoch 164/199
# ----------
# train Loss: 0.3075 Acc: 0.8670
# val Loss: 0.3646 Acc: 0.8420
#
# Epoch 165/199
# ----------
# train Loss: 0.3026 Acc: 0.8667
# val Loss: 0.3706 Acc: 0.8413
#
# Epoch 166/199
# ----------
# train Loss: 0.3015 Acc: 0.8653
# val Loss: 0.3648 Acc: 0.8463
#
# Epoch 167/199
# ----------
# train Loss: 0.2985 Acc: 0.8653
# val Loss: 0.3763 Acc: 0.8387
#
# Epoch 168/199
# ----------
# train Loss: 0.3062 Acc: 0.8683
# val Loss: 0.3651 Acc: 0.8477
#
# Epoch 169/199
# ----------
# train Loss: 0.3091 Acc: 0.8603
# val Loss: 0.3656 Acc: 0.8467
#
# Epoch 170/199
# ----------
# train Loss: 0.3010 Acc: 0.8693
# val Loss: 0.3662 Acc: 0.8457
#
# Epoch 171/199
# ----------
# train Loss: 0.3040 Acc: 0.8670
# val Loss: 0.3679 Acc: 0.8420
#
# Epoch 172/199
# ----------
# train Loss: 0.2936 Acc: 0.8720
# val Loss: 0.3745 Acc: 0.8427
#
# Epoch 173/199
# ----------
# train Loss: 0.3080 Acc: 0.8683
# val Loss: 0.3732 Acc: 0.8413
#
# Epoch 174/199
# ----------
# train Loss: 0.3055 Acc: 0.8640
# val Loss: 0.3684 Acc: 0.8433
#
# Epoch 175/199
# ----------
# train Loss: 0.3012 Acc: 0.8680
# val Loss: 0.3693 Acc: 0.8437
#
# Epoch 176/199
# ----------
# train Loss: 0.3206 Acc: 0.8567
# val Loss: 0.3719 Acc: 0.8420
#
# Epoch 177/199
# ----------
# train Loss: 0.3065 Acc: 0.8707
# val Loss: 0.3678 Acc: 0.8457
#
# Epoch 178/199
# ----------
# train Loss: 0.2981 Acc: 0.8687
# val Loss: 0.3686 Acc: 0.8440
#
# Epoch 179/199
# ----------
# train Loss: 0.3071 Acc: 0.8627
# val Loss: 0.3729 Acc: 0.8433
#
# Epoch 180/199
# ----------
# train Loss: 0.3010 Acc: 0.8620
# val Loss: 0.3743 Acc: 0.8383
#
# Epoch 181/199
# ----------
# train Loss: 0.3038 Acc: 0.8650
# val Loss: 0.3682 Acc: 0.8437
#
# Epoch 182/199
# ----------
# train Loss: 0.3181 Acc: 0.8623
# val Loss: 0.3728 Acc: 0.8447
#
# Epoch 183/199
# ----------
# train Loss: 0.3043 Acc: 0.8650
# val Loss: 0.3685 Acc: 0.8443
#
# Epoch 184/199
# ----------
# train Loss: 0.3010 Acc: 0.8677
# val Loss: 0.3722 Acc: 0.8440
#
# Epoch 185/199
# ----------
# train Loss: 0.3175 Acc: 0.8533
# val Loss: 0.3685 Acc: 0.8417
#
# Epoch 186/199
# ----------
# train Loss: 0.3010 Acc: 0.8630
# val Loss: 0.3683 Acc: 0.8447
#
# Epoch 187/199
# ----------
# train Loss: 0.2986 Acc: 0.8677
# val Loss: 0.3764 Acc: 0.8423
#
# Epoch 188/199
# ----------
# train Loss: 0.3052 Acc: 0.8670
# val Loss: 0.3744 Acc: 0.8443
#
# Epoch 189/199
# ----------
# train Loss: 0.3076 Acc: 0.8650
# val Loss: 0.3705 Acc: 0.8447
#
# Epoch 190/199
# ----------
# train Loss: 0.2937 Acc: 0.8703
# val Loss: 0.3731 Acc: 0.8433
#
# Epoch 191/199
# ----------
# train Loss: 0.2984 Acc: 0.8687
# val Loss: 0.3686 Acc: 0.8447
#
# Epoch 192/199
# ----------
# train Loss: 0.3001 Acc: 0.8633
# val Loss: 0.3718 Acc: 0.8400
#
# Epoch 193/199
# ----------
# train Loss: 0.2974 Acc: 0.8653
# val Loss: 0.3689 Acc: 0.8437
#
# Epoch 194/199
# ----------
# train Loss: 0.2985 Acc: 0.8713
# val Loss: 0.3703 Acc: 0.8413
#
# Epoch 195/199
# ----------
# train Loss: 0.3071 Acc: 0.8653
# val Loss: 0.3719 Acc: 0.8443
#
# Epoch 196/199
# ----------
# train Loss: 0.2989 Acc: 0.8670
# val Loss: 0.3722 Acc: 0.8437
#
# Epoch 197/199
# ----------
# train Loss: 0.2899 Acc: 0.8627
# val Loss: 0.3713 Acc: 0.8447
#
# Epoch 198/199
# ----------
# train Loss: 0.3007 Acc: 0.8690
# val Loss: 0.3752 Acc: 0.8440
#
# Epoch 199/199
# ----------
# train Loss: 0.3003 Acc: 0.8690
# val Loss: 0.3738 Acc: 0.8390
#
# Training complete in 19m 30s
# Best val Acc: 0.847667

# %% [markdown]
# ### plot loss and accuracy

# %%
print(hist.keys())

#### Fill in plot #####
#Plot accuracy vs epoch
plt.subplot(211)

plt.plot(hist['train_acc'])
plt.plot(hist['val_acc'])
plt.title('accuracy : mnasnet1.0')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

#Plot loss vs epoch
plt.subplot(212)
plt.plot(hist['train_loss'])
plt.plot(hist['val_loss'])
plt.title('loss : mnasnet1.0')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

print(best_acc)
# Out:
# dict_keys(['train_loss', 'train_acc', 'val_loss', 'val_acc'])
# tensor(0.8477, device='cuda:0', dtype=torch.float64)

# %% [markdown]
# ### load model and prediction

# %%
def forward_vis(vis_loader, groups):
    since = time.time()
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = models.mnasnet1_0()
    set_parameter_requires_grad(model, feature_extract)
    model.classifier = nn.Sequential(nn.Dropout(p=0.2, inplace=True), nn.Linear(1280, num_classes))
    # load best model weights
    model.load_state_dict(torch.load('model_weight/mnasnet_'+str(num_epochs)))
    model.to(device)
    model.eval()   # Set model to evaluate mode
    # Iterate over data.
    cnt=0
    vis_dict = {'inputs':np.empty([groups,vis_batch,3,224,224]),'outputs':np.empty([groups,vis_batch,num_classes]),'labels':np.empty([groups,vis_batch]),'preds':np.empty([groups,vis_batch])}
    for inputs, labels in vis_loader:
            if(cnt==groups):
                break;
            
            inputs = inputs.to(device)
            labels = labels.to(device)
            vis_dict['inputs'][cnt,:,:,:,:]=inputs.cpu().numpy()
            vis_dict['labels'][cnt,:]=labels.cpu().numpy()
            # forward
            # track history if only in train
            with torch.set_grad_enabled(False):
            # Get model outputs and calculate loss
            # Special case for inception because in training it has an auxiliary output. In train
            #   mode we calculate the loss by summing the final output and the auxiliary output
            #   but in testing we only consider the final output.
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                vis_dict['outputs'][cnt,:,:]=outputs.cpu().numpy()
                vis_dict['preds'][cnt,:]=preds.cpu().numpy()
            cnt+=1
            

    time_elapsed = time.time() - since
    print()
    print('Inference complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    return vis_dict

vis_loader = torch.utils.data.DataLoader(image_datasets['val'], batch_size=vis_batch, shuffle=True, num_workers=8)
vis_dict = forward_vis(vis_loader, groups)
print(vis_dict['inputs'].shape)
print(vis_dict['outputs'].shape)
print(vis_dict['labels'].shape)
print(vis_dict['preds'].shape)
# Out:
# Inference complete in 0m 1s
# (3, 4, 3, 224, 224)
# (3, 4, 2)
# (3, 4)
# (3, 4)

# %% [markdown]
# ### visualization

# %%
for i in range(groups) :
    for j in range(vis_batch) :
        plt.figure(figsize=(15,15))
        plt.subplot(groups,vis_batch,4*i+j+1)
        image = np.moveaxis(np.squeeze(vis_dict['inputs'][i,j]), 0, -1)
        image = (image-np.amin(image))/(np.amax(image)-np.amin(image))
        plt.imshow(image)
        plt.tick_params(
        axis='both',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        left=False,         # ticks along the left edge are off
        labelbottom=False,
        labelleft=False) # labels along the bottom edge are off
        plt.title('preprocessed '+str(i)+' '+str(j))
        plt.xlabel('label : '+str(vis_dict['labels'][i,j])+', pred : '+str(vis_dict['preds'][i,j])+', output : '+str(vis_dict['outputs'][i,j,:]))
plt.show()
